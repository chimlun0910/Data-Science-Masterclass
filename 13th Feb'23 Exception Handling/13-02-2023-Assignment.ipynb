# %% [markdown]
# **Q1. Explain why we have to use the Exception class while creating a Custom Exception.**
#
# - We have to use Exception class because it's is the base class of all Specific Built-in Exception. So that, if we want to create a Custom Eception, we have to create a custom Exception class that inherit all the properties of Exception class.

# %% [markdown]
# **Q2. Write a python program to print Python Exception Hierarchy.**

# %%
import inspect

# %%
def tree_class(cls, ind = 0):
    print ('-' * ind, cls.__name__)
      
    for i in cls.__subclasses__():
        tree_class(i, ind + 3)

# %%
print("Hierarchy for exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
tree_class(BaseException)
# Out:
# Hierarchy for exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# --------- UFuncTypeError
# ------------ UFuncTypeError
# ------------ UFuncTypeError
# ------------ UFuncTypeError
# --------------- UFuncTypeError
# --------------- UFuncTypeError
# --------- ConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# ------------ ExecutableNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# ...

# %% [markdown]
# **Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.**
#
# - The base class for those built-in exceptions that are raised for various arithmetic errors: OverflowError, ZeroDivisionError, FloatingPointError.

# %%
try:
    a = 10
    a / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
import math

# %%
try:
    print(math.exp(1000))
except OverflowError as e:
    print(e)
# Out:
# math range error

# %% [markdown]
# **Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.**
#
# - The base class for exceptions that are raised when a key or an index used on mapping or sequence is invalid: IndexError, KeyError

# %%
l = [1, 2, 3, 4, 5]

# %%
try: 
    print("The 10th element of the list l is: {}".format(l[10]))
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
d = {"course": ["data science masterclass", "web dev", "java with dsa and system design"], "lecturer": ["Krish", "Sudh"]}

# %%
try:
    print("The key 'Course' in the dictionary d has value {}".format(d["Course"]))
except KeyError as e:
    print(e)
# Out:
# 'Course'

# %% [markdown]
# **Q5. Explain ImportError. What is ModuleNotFoundError?**
#
# - ImportError: Raised when the import statement has troubles trying to load a module. Also raised when the “from list” in from ... import has a name that cannot be found.
#
# - ModuleNotFoundError: A subclass of ImportError which is raised by import when a module could not be located.

# %% [markdown]
# **Q6. List down some best practices for exception handling in python.**
#
# - Always use a specific exception.
# - Print a valid message.
# - Always try to log.
# - Always try to avoid multiple exceptions.
# - Prepare a proper documentation.
# - Clean up all the resources.
