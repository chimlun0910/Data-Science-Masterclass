# %% [markdown]
# **Q1. What is Flask Framework? What are the advantages of Flask Framework?**
#
# - Flask is a web application framework written in Python. Flask is based on the Werkzeg WSGI toolkit and the Jinja2 template engine.Both are Pocco projects.
#
# - Advantages:
#     - Scalable.
#     - Simpler Development.
#     - Flexibility.
#     - Performance.
#     - Modularity.

# %% [markdown]
# **Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.**

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def welcome():
    return "pwskills"

@app.route("/helloworld")
def hello_world():
    return "<h2>Hello World!!</h2>"

if __name__ == "__main__":
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.100:5000
# Press CTRL+C to quit
# 192.168.1.100 - - [20/Feb/2023 13:59:05] "GET / HTTP/1.1" 200 -
# 192.168.1.100 - - [20/Feb/2023 13:59:13] "GET /helloworld HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q3. What is App routing in Flask? Why do we use app routes?**
#
# - To bind a function to an URL path we use the app.route decorator. App Routing helps mapping the URLs to the specific function that will handle the logic for that URL.

# %% [markdown]
# **Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:**
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

@app.route("/")
def display_details():
    return """
<div>Company Name: ABC Corporation</div>

<div>Location: India</div>

<div>Contact Detail: 999-999-9999</div>
"""

if __name__ == "__main__":
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.100:5000
# Press CTRL+C to quit
# 192.168.1.100 - - [20/Feb/2023 14:07:21] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.**
#
# - The url_for() is used to build a URL to the specific function dynamically. The first argument of the function is the name of the specified function, and one or more keyword arguments, each corresponding to the variable part of URL.

# %%
from flask import Flask, redirect, url_for

app = Flask(__name__)

@app.route("/admin")
def hello_admin():
    return "Hello Admin"

@app.route("/guest")
def hello_guest():
    return "Hello Guest"

@app.route("/student")
def hello_student():
    return "Hello Student"

@app.route("/user/<name>")
def hello_user(name):
    if name == "admin":
        return redirect(url_for("hello_admin"))
    if name == "guest":
        return redirect(url_for("guest"))
    if name == "student":
        return redirect(url_for("student"))

if __name__ == "__main__":
    app.run("0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.100:5000
# Press CTRL+C to quit
# 192.168.1.100 - - [20/Feb/2023 14:25:37] "GET / HTTP/1.1" 404 -
# 192.168.1.100 - - [20/Feb/2023 14:25:41] "GET /user/admin HTTP/1.1" 302 -
# 192.168.1.100 - - [20/Feb/2023 14:25:41] "GET /admin HTTP/1.1" 200 -
